# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-0.99, 0.91, 100)
y = (1+x)/np.sqrt(1 - x**2)
plt.title(r'$y = \frac{1+x}{\sqrt{1 - x^2}}$')
plt.plot(x, y)
plt.savefig('equation_share.pdf')
