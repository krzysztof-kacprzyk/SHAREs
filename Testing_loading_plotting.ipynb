# %%
from load_data import load_data

# %%
load_data('boston')
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# 2       17.8  392.83   4.03    34.7
# 3       18.7  394.63   2.94    33.4
# 4       18.7  396.90   5.33    36.2
# ..       ...     ...    ...     ...
# 501     21.0  391.99   9.67    22.4
# 502     21.0  396.90   9.08    20.6
# 503     21.0  396.90   5.64    23.9
# 504     21.0  393.45   6.48    22.0
# 505     21.0  396.90   7.88    11.9
#
# [506 rows x 14 columns]

# %%
california = load_data('california')

# %%
california
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  target
# 0        -122.23   4.526
# 1        -122.22   3.585
# 2        -122.24   3.521
# 3        -122.25   3.413
# 4        -122.25   3.422
# ...          ...     ...
# 20635    -121.09   0.781
# 20636    -121.21   0.771
# 20637    -121.22   0.923
# 20638    -121.32   0.847
# 20639    -121.24   0.894
#
# [20640 rows x 9 columns]

# %%
from benchmarks import load_df

# %%
df = load_df('adult','classification')

# %%
df
# Out:
#         age  workclass    fnlwgt  education  education-num  marital-status  \
# 0      39.0          7   77516.0          9           13.0               4
# 1      50.0          6   83311.0          9           13.0               2
# 2      38.0          4  215646.0         11            9.0               0
# 3      53.0          4  234721.0          1            7.0               2
# 4      28.0          4  338409.0          9           13.0               2
# ...     ...        ...       ...        ...            ...             ...
# 48837  39.0          4  215419.0          9           13.0               0
# 48838  64.0          0  321403.0         11            9.0               6
# 48839  38.0          4  374983.0          9           13.0               2
# 48840  44.0          4   83891.0          9           13.0               0
# 48841  35.0          5  182148.0          9           13.0               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0               1             1     4    1        2174.0           0.0
# 1               4             0     4    1           0.0           0.0
# 2               6             1     4    1           0.0           0.0
# 3               6             0     2    1           0.0           0.0
# 4              10             5     2    0           0.0           0.0
# ...           ...           ...   ...  ...           ...           ...
# 48837          10             1     4    0           0.0           0.0
# 48838           0             2     2    1           0.0           0.0
# 48839          10             0     4    1           0.0           0.0
# 48840           1             3     1    1        5455.0           0.0
# 48841           4             0     4    1           0.0           0.0
#
#        hours-per-week  native-country  target
# 0                40.0              39       1
# 1                13.0              39       1
# 2                40.0              39       1
# 3                40.0              39       1
# 4                40.0               5       1
# ...               ...             ...     ...
# 48837            36.0              39       1
# 48838            40.0              39       1
# 48839            50.0              39       1
# 48840            40.0              39       1
# 48841            60.0              39       0
#
# [48842 rows x 15 columns]

# %%
from benchmarks import load_df

# %%
df = load_df('wine_quality_red','regression')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  target
# 0         9.4       5
# 1         9.8       5
# 2         9.8       5
# 3         9.8       6
# 4         9.4       5
# ...       ...     ...
# 1594     10.5       5
# 1595     11.2       6
# 1596     11.0       6
# 1597     10.2       5
# 1598     11.0       6
#
# [1599 rows x 12 columns]

# %%
from utils import load_share_from_checkpoint
from benchmarks import create_categorical_variable_dict, categorical_variables_per_dataset, load_df
import pandas as pd
import os
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer, OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
timestamp = "2023-03-16T11.59.15"
dictionary_path = os.path.join('checkpoints',timestamp,'dictionary.csv')
df = pd.read_csv(dictionary_path, index_col=False)

# %%
eq1 = df.sort_values(by='r2',ascending=False).iloc[0,:]

# %%
for i in range(10):
    print(df.sort_values(by='r2',ascending=False).iloc[i,:][['id','equation']])
# Out:
# id                                                        522
# equation    shape(mul(div(mul(mul(mul(add(div(add(div(mul(...
# Name: 522, dtype: object
# id                                                        473
# equation    shape(mul(div(mul(mul(mul(add(div(add(div(mul(...
# Name: 473, dtype: object
# id                                                        430
# equation    shape(mul(mul(mul(mul(mul(add(div(add(div(mul(...
# Name: 430, dtype: object
# id                                                        306
# equation    shape(mul(mul(div(mul(mul(add(div(add(div(mul(...
# Name: 306, dtype: object
# id                                                        379
# equation    shape(mul(mul(div(mul(mul(add(div(add(div(mul(...
# Name: 379, dtype: object
# id                                                         57
# equation    shape(mul(mul(div(mul(div(add(div(add(div(mul(...
# Name: 57, dtype: object
# id                                                        337
# equation    shape(mul(add(div(mul(mul(add(div(add(div(mul(...
# Name: 337, dtype: object
# id                                                        336
# equation    shape(div(mul(div(div(add(add(div(add(mul(mul(...
# Name: 336, dtype: object
# id                                                        420
# equation    shape(mul(mul(div(mul(mul(add(div(add(shape(di...
# Name: 420, dtype: object
# id                                                        246
# equation    shape(mul(mul(div(mul(div(add(mul(add(div(mul(...
# Name: 246, dtype: object

# %%
categorical_variable_dict = create_categorical_variable_dict('boston','regression')
esr = load_share_from_checkpoint(timestamp, eq1['equation'], checkpoint_dir='checkpoints', task='regression',n_features=13,equation_id=eq1['id'], categorical_variables_dict=categorical_variable_dict)
# Out:
# shape(mul(div(mul(mul(mul(add(div(add(div(mul(div(add(shape(X5), shape(X4)), shape(X10)), shape(X12)), shape(X1)), shape(X7)), shape(X9)), shape(X8)), shape(X0)), shape(X11)), shape(X3)), shape(X2)), shape(X6)))

# %%
def get_preprocessed_data(dataset_name,task):
    dataset = load_df(dataset_name,task)
    X = dataset.drop(columns=['target'])
    y = dataset[['target']]

    categorical_variables = categorical_variables_per_dataset[dataset_name]
    is_cat = np.array([i in categorical_variables for i in range(len(X.columns))])

    cat_cols = X.columns.values[is_cat]
    num_cols = X.columns.values[~is_cat]

    categories = []
    for i in categorical_variables:
        uniques = list(X.iloc[:,i].unique())
        categories.append(sorted(uniques))
    
    cat_pipe = Pipeline([('ordinal', OrdinalEncoder(categories=categories))])
    num_pipe = Pipeline([('std',StandardScaler())])
    transformers = [
        ('cat', cat_pipe, cat_cols),
        ('num', num_pipe, num_cols)
    ]
    ct = ColumnTransformer(transformers=transformers)
    
    processing = Pipeline([
        ('ct',ct),
    ])

    if task == 'classification':
        # Identity transformer for classification
        y_scaler = FunctionTransformer(lambda x: x.values)
    else:
        y_scaler = StandardScaler()

    X = processing.fit_transform(X)
    y = y_scaler.fit_transform(y)[:,0]

    return X,y

# %%
X,y = get_preprocessed_data('boston','regression')

# %%
shape_ranges = esr.get_shape_ranges(X)
# Out:
# c:\Users\krkac\Miniconda3\envs\share\lib\site-packages\sklearn\preprocessing\_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# c:\Users\krkac\Miniconda3\envs\share\lib\site-packages\sklearn\preprocessing\_encoders.py:808: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
shape_ranges
# Out:
# {1: (-1.4658819437026978, 2.732346534729004),
#  2: (-1.5578417778015137, 2.422565221786499),
#  3: (-2.707379102706909, 1.6388282775878906),
#  4: (-1.5311270952224731, 3.5487709045410156),
#  5: (-2.335437059402466, 1.1174944639205933),
#  6: (-1.3139899969100952, 1.798194169998169),
#  7: (-1.2670692205429077, 3.960517644882202),
#  8: (-3.907193422317505, 0.4410519301891327),
#  9: (-0.48772236704826355, 3.804234504699707),
#  10: (-0.41978195309638977, 9.933930397033691),
#  11: (-3.880249261856079, 3.555044174194336),
#  0: (-423.54705810546875, -88.4694595336914)}

# %%
esr.categorical_variables
# Out:
# {0: 2, 1: 9}

# %%
esr._program.plot_shape_functions_given_ranges(shape_ranges)

# %%
df.sort_values(by='r2',ascending=False).head(20)
# Out:
#       id                                           equation  raw_fitness  \
# 522  522  shape(mul(div(mul(mul(mul(add(div(add(div(mul(...     0.064211
# 473  473  shape(mul(div(mul(mul(mul(add(div(add(div(mul(...     0.064211
# 430  430  shape(mul(mul(mul(mul(mul(add(div(add(div(mul(...     0.064561
# 306  306  shape(mul(mul(div(mul(mul(add(div(add(div(mul(...     0.064581
# 379  379  shape(mul(mul(div(mul(mul(add(div(add(div(mul(...     0.064665
# 57    57  shape(mul(mul(div(mul(div(add(div(add(div(mul(...     0.066214
# 337  337  shape(mul(add(div(mul(mul(add(div(add(div(mul(...     0.068162
# 336  336  shape(div(mul(div(div(add(add(div(add(mul(mul(...     0.068726
# 420  420  shape(mul(mul(div(mul(mul(add(div(add(shape(di...     0.069872
# 246  246  shape(mul(mul(div(mul(div(add(mul(add(div(mul(...     0.071760
# 289  289  shape(mul(mul(div(add(div(add(div(add(div(mul(...     0.073045
# 319  319  shape(mul(mul(mul(div(div(add(div(add(add(mul(...     0.074926
# 401  401  shape(mul(add(div(mul(mul(add(div(add(div(mul(...     0.075112
# 299  299  shape(mul(mul(div(mul(div(add(div(add(div(mul(...     0.079021
# 447  447  shape(mul(mul(div(mul(mul(add(div(add(div(mul(...     0.079820
# 226  226  shape(mul(mul(div(mul(div(add(div(add(mul(mul(...     0.080031
# 512  512  shape(mul(mul(mul(add(div(add(div(mul(mul(add(...     0.080577
# 227  227  shape(mul(mul(div(mul(div(add(div(add(div(shap...     0.080619
# 217  217  shape(mul(mul(div(mul(div(add(div(add(div(mul(...     0.081471
# 325  325  shape(mul(mul(mul(mul(div(add(div(add(div(mul(...     0.081619
#
#            r2
# 522  0.935789
# 473  0.935789
# 430  0.935439
# 306  0.935419
# 379  0.935335
# 57   0.933786
# 337  0.931838
# 336  0.931274
# 420  0.930128
# 246  0.928240
# 289  0.926955
# 319  0.925074
# 401  0.924888
# 299  0.920979
# 447  0.920180
# 226  0.919969
# 512  0.919423
# 227  0.919381
# 217  0.918529
# 325  0.918381
